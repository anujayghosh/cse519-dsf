# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('yelp_reviews.csv')
# df = df.drop(columns=['Unnamed: 0'])
df.head()
# Out:
#    Unnamed: 0                      id                   alias            name  \
# 0        5744  pNbrxyrG5d5QwRsKbu0cXg             46-new-york              46
# 1       13902  8Oo2AtQEPDfxIOnA8wfXoQ            886-new-york             886
# 2          95  fNKYBpQJivICm0ORb3nb_Q         8282-new-york-2            8282
# 3       22197  Xu1jidsfdN0Wb3RMII3abw        apr57-new-york-2          Apr-57
# 4       11459  cuqT0Venx12D4bil06J1UA  purnima-halal-brooklyn   Purnima Halal
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/PDgpYA...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/N-V-Dl...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/jMQtrS...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/osmh-5...      False
# 4                                                NaN      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/46-new-york?adjust_cr...            97
# 1  https://www.yelp.com/biz/886-new-york?adjust_c...           693
# 2  https://www.yelp.com/biz/8282-new-york-2?adjus...           178
# 3  https://www.yelp.com/biz/apr57-new-york-2?adju...            28
# 4  https://www.yelp.com/biz/purnima-halal-brookly...             1
#
#                                           categories  rating  ...  longitude  \
# 0       [{'alias': 'desserts', 'title': 'Desserts'}]     4.5  ... -73.998644
# 1  [{'alias': 'taiwanese', 'title': 'Taiwanese'},...     4.0  ... -73.988730
# 2           [{'alias': 'korean', 'title': 'Korean'}]     4.5  ... -73.988750
# 3  [{'alias': 'jewelry', 'title': 'Jewelry'}, {'a...     2.5  ... -73.980528
# 4         [{'alias': 'grocery', 'title': 'Grocery'}]     5.0  ... -73.951040
#
#   zip_codes            address  \
# 0     10013         46 Mott St
# 1     10003  26 Saint Marks Pl
# 2     10002      84 Stanton St
# 3     10019      200 W 57th St
# 4     11216     1257 Fulton St
#
#                                         review_texts review_ratings  \
# 0  ["Cash only for transactions under $5. \n\nAma...      [5, 3, 4]
# 1  ["Love that this place kind of mimic the Asian...      [5, 4, 1]
# 2  ["This is a small Korean fusion tapas restaura...      [5, 5, 5]
# 3                                                NaN            NaN
# 4  ["Wide selection, all clean and new. Welcoming...            [5]
#
#                                         review_times  chain_id_cosine  \
# 0  ["2023-05-14 12:05:28", "2023-08-23 20:49:11",...              NaN
# 1  ["2023-10-15 19:30:27", "2023-11-11 17:09:46",...              1.0
# 2  ["2023-11-08 19:11:14", "2023-10-26 22:42:57",...              2.0
# 3                                                NaN              3.0
# 4                            ["2018-03-20 02:10:06"]              4.0
#
#    chain_id_jaccard  chain_id_levenshtein chain_id_fuzzy
# 0               NaN                   NaN            NaN
# 1               1.0                   1.0            1.0
# 2               2.0                   2.0            2.0
# 3               3.0                   3.0            3.0
# 4               4.0                   4.0            4.0
#
# [5 rows x 28 columns]

# %%
# Function to normalize names
def normalize_name(name):
    return ''.join(e for e in name if e.isalnum()).lower()

df['normalized_name'] = df['name'].apply(normalize_name)
    
# # Sort DataFrame based on the normalized 'name' column
# df.sort_values(by='normalized_name', inplace=True)

# %%
df
# Out:
#        Unnamed: 0                      id  \
# 0            5744  pNbrxyrG5d5QwRsKbu0cXg
# 1           13902  8Oo2AtQEPDfxIOnA8wfXoQ
# 2              95  fNKYBpQJivICm0ORb3nb_Q
# 3           22197  Xu1jidsfdN0Wb3RMII3abw
# 4           11459  cuqT0Venx12D4bil06J1UA
# ...           ...                     ...
# 21664         712  abNHO9-xlCsv31gghCUuxw
# 21665       18003  6ebOnjQ7An6J94Sv7qkfRQ
# 21666       11100  3FzpZE56CHuipiY_JDT3EA
# 21667       24086  3ZRU-srtIKQ5uf9S3EYKig
# 21668       29618  VIcZAaBOz8iF1DEHxvmxAw
#
#                                         alias                         name  \
# 0                                 46-new-york                           46
# 1                                886-new-york                          886
# 2                             8282-new-york-2                         8282
# 3                            apr57-new-york-2                       Apr-57
# 4                      purnima-halal-brooklyn                Purnima Halal
# ...                                       ...                          ...
# 21664  zutto-japanese-american-pub-new-york-2  Zutto Japanese American Pub
# 21665                   zuzus-petals-brooklyn                Zuzu's Petals
# 21666              zyara-restaurant-astoria-2             Zyara Restaurant
# 21667                    zyoga-space-new-york                  Zyoga Space
# 21668                     zz-day-spa-new-york                   ZZ Day Spa
#
#                                                image_url  is_closed  \
# 0      https://s3-media3.fl.yelpcdn.com/bphoto/PDgpYA...      False
# 1      https://s3-media3.fl.yelpcdn.com/bphoto/N-V-Dl...      False
# 2      https://s3-media2.fl.yelpcdn.com/bphoto/jMQtrS...      False
# 3      https://s3-media1.fl.yelpcdn.com/bphoto/osmh-5...      False
# 4                                                    NaN      False
# ...                                                  ...        ...
# 21664  https://s3-media3.fl.yelpcdn.com/bphoto/kNweT2...      False
# 21665  https://s3-media1.fl.yelpcdn.com/bphoto/02bT9I...      False
# 21666  https://s3-media3.fl.yelpcdn.com/bphoto/ZxC5z2...      False
# 21667  https://s3-media2.fl.yelpcdn.com/bphoto/mxB1FT...      False
# 21668  https://s3-media3.fl.yelpcdn.com/bphoto/Ba2wZI...      False
#
#                                                      url  review_count  \
# 0      https://www.yelp.com/biz/46-new-york?adjust_cr...            97
# 1      https://www.yelp.com/biz/886-new-york?adjust_c...           693
# 2      https://www.yelp.com/biz/8282-new-york-2?adjus...           178
# 3      https://www.yelp.com/biz/apr57-new-york-2?adju...            28
# 4      https://www.yelp.com/biz/purnima-halal-brookly...             1
# ...                                                  ...           ...
# 21664  https://www.yelp.com/biz/zutto-japanese-americ...          1027
# 21665  https://www.yelp.com/biz/zuzus-petals-brooklyn...            92
# 21666  https://www.yelp.com/biz/zyara-restaurant-asto...           325
# 21667  https://www.yelp.com/biz/zyoga-space-new-york?...             1
# 21668  https://www.yelp.com/biz/zz-day-spa-new-york?a...           189
#
#                                               categories  rating  ...  \
# 0           [{'alias': 'desserts', 'title': 'Desserts'}]     4.5  ...
# 1      [{'alias': 'taiwanese', 'title': 'Taiwanese'},...     4.0  ...
# 2               [{'alias': 'korean', 'title': 'Korean'}]     4.5  ...
# 3      [{'alias': 'jewelry', 'title': 'Jewelry'}, {'a...     2.5  ...
# 4             [{'alias': 'grocery', 'title': 'Grocery'}]     5.0  ...
# ...                                                  ...     ...  ...
# 21664  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0  ...
# 21665  [{'alias': 'florists', 'title': 'Florists'}, {...     4.0  ...
# 21666  [{'alias': 'halal', 'title': 'Halal'}, {'alias...     3.5  ...
# 21667               [{'alias': 'yoga', 'title': 'Yoga'}]     5.0  ...
# 21668  [{'alias': 'waxing', 'title': 'Waxing'}, {'ali...     5.0  ...
#
#       zip_codes            address  \
# 0         10013         46 Mott St
# 1         10003  26 Saint Marks Pl
# 2         10002      84 Stanton St
# 3         10019      200 W 57th St
# 4         11216     1257 Fulton St
# ...         ...                ...
# 21664     10013       77 Hudson St
# 21665     11215        374 5th Ave
# 21666     11103  25-53 Steinway St
# 21667     10023   162 West 72nd St
# 21668     10022     120 East 56 St
#
#                                             review_texts  review_ratings  \
# 0      ["Cash only for transactions under $5. \n\nAma...       [5, 3, 4]
# 1      ["Love that this place kind of mimic the Asian...       [5, 4, 1]
# 2      ["This is a small Korean fusion tapas restaura...       [5, 5, 5]
# 3                                                    NaN             NaN
# 4      ["Wide selection, all clean and new. Welcoming...             [5]
# ...                                                  ...             ...
# 21664  ["I don't know why I stopped in... maybe cuz I...       [4, 4, 5]
# 21665                                                NaN             NaN
# 21666  ["I came here for a family dinner - the decor ...       [4, 1, 3]
# 21667                                                NaN             NaN
# 21668                                                NaN             NaN
#
#                                             review_times  chain_id_cosine  \
# 0      ["2023-05-14 12:05:28", "2023-08-23 20:49:11",...              NaN
# 1      ["2023-10-15 19:30:27", "2023-11-11 17:09:46",...              1.0
# 2      ["2023-11-08 19:11:14", "2023-10-26 22:42:57",...              2.0
# 3                                                    NaN              3.0
# 4                                ["2018-03-20 02:10:06"]              4.0
# ...                                                  ...              ...
# 21664  ["2023-09-25 12:36:19", "2023-09-23 10:06:16",...          19682.0
# 21665                                                NaN          19683.0
# 21666  ["2023-06-24 12:31:40", "2023-07-17 06:11:04",...          19684.0
# 21667                                                NaN          19685.0
# 21668                                                NaN          19687.0
#
#        chain_id_jaccard  chain_id_levenshtein  chain_id_fuzzy  \
# 0                   NaN                   NaN             NaN
# 1                   1.0                   1.0             1.0
# 2                   2.0                   2.0             2.0
# 3                   3.0                   3.0             3.0
# 4                   4.0                   4.0             4.0
# ...                 ...                   ...             ...
# 21664           18513.0               19342.0         18831.0
# 21665           18514.0               19343.0         18832.0
# 21666           18515.0               19344.0         18833.0
# 21667           18516.0               19345.0         18834.0
# 21668           18518.0               19347.0         18836.0
#
#                 normalized_name
# 0                            46
# 1                           886
# 2                          8282
# 3                         apr57
# 4                  purnimahalal
# ...                         ...
# 21664  zuttojapaneseamericanpub
# 21665               zuzuspetals
# 21666           zyararestaurant
# 21667                zyogaspace
# 21668                  zzdayspa
#
# [21669 rows x 29 columns]

# %%
from ast import literal_eval
# Flatten the list of review ratings, ignoring NaN entries
df['review_ratings'] = df['review_ratings'].apply(literal_eval)

# %%
# Flatten the list of review ratings, ignoring NaN entries
flat_ratings = [rating for sublist in df['review_ratings'].dropna() for rating in sublist]

# Plot the distribution using a histogram
plt.figure(figsize=(8, 6))
plt.hist(flat_ratings, bins=range(1, 7), align='left', edgecolor='black', alpha=0.7)
plt.xlabel('Review Ratings')
plt.ylabel('Frequency')
plt.title('Distribution of Review Ratings (Ignoring NaN)')
plt.xticks(range(1, 6))
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Count occurrences of each star rating and print labels with counts
rating_counts = pd.Series(flat_ratings).value_counts().sort_index()
for rating, count in rating_counts.items():
    plt.text(rating, count, f'{rating} Stars\nCount: {count}', ha='center', va='bottom')

plt.show()

# %%
len(flat_ratings)
# Out:
# 32649

# %%
df["categories"]
# Out:
# 0             [{'alias': 'desserts', 'title': 'Desserts'}]
# 1        [{'alias': 'taiwanese', 'title': 'Taiwanese'},...
# 2                 [{'alias': 'korean', 'title': 'Korean'}]
# 3        [{'alias': 'jewelry', 'title': 'Jewelry'}, {'a...
# 4               [{'alias': 'grocery', 'title': 'Grocery'}]
#                                ...
# 21664    [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...
# 21665    [{'alias': 'florists', 'title': 'Florists'}, {...
# 21666    [{'alias': 'halal', 'title': 'Halal'}, {'alias...
# 21667                 [{'alias': 'yoga', 'title': 'Yoga'}]
# 21668    [{'alias': 'waxing', 'title': 'Waxing'}, {'ali...
# Name: categories, Length: 21669, dtype: object

# %%
# Convert the 'categories' strings to actual lists of dictionaries
df['categories'] = df['categories'].apply(literal_eval)

# %%
from collections import Counter
# Flatten the list of dictionaries and extract 'title' values
category_titles = [category['title'] for sublist in df['categories'].dropna() for category in sublist]

# Count the occurrences of each category title
category_counts = Counter(category_titles)

# Select the top 10 most popular categories
top_categories = dict(category_counts.most_common(20))

# Plot the bar chart using seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x=list(top_categories.values()), y=list(top_categories.keys()), palette="viridis")
plt.xlabel('Number of Businesses')
plt.ylabel('Category Title')
plt.title('Top 20 Most Popular Categories')
plt.show()

# %%
import pandas as pd
from textblob import TextBlob
from ast import literal_eval

# %%
# Convert string representations of lists to actual lists
df['review_texts'] = df['review_texts'].apply(lambda x: literal_eval(x) if pd.notna(x) else [])

# Apply sentiment analysis using TextBlob, considering NaN values
df['sentiment'] = df['review_texts'].apply(lambda reviews: TextBlob(" ".join(reviews)).sentiment.polarity if reviews else None)

# Display the DataFrame
print(df[['review_texts', 'sentiment']])
# Out:
#                                             review_texts  sentiment
# 0      [Cash only for transactions under $5. \n\nAmaz...   0.052778
# 1      [Love that this place kind of mimic the Asian ...   0.145909
# 2      [This is a small Korean fusion tapas restauran...   0.277778
# 3                                                     []        NaN
# 4      [Wide selection, all clean and new. Welcoming ...   0.229004
# ...                                                  ...        ...
# 21664  [I don't know why I stopped in... maybe cuz I ...   0.380386
# 21665                                                 []        NaN
# 21666  [I came here for a family dinner - the decor o...   0.131597
# 21667                                                 []        NaN
# 21668                                                 []        NaN
#
# [21669 rows x 2 columns]

# %%
# Plot the histogram of sentiment values with lines for neutrality, positive, and negative
plt.figure(figsize=(8, 6))
plt.hist(df['sentiment'].dropna(), bins=20, edgecolor='black', color='skyblue', alpha=0.7)
plt.axvline(x=0, color='red', linestyle='--', label='Neutral')
# plt.axvline(x=0.2, color='green', linestyle='--', label='Positive')
# plt.axvline(x=-0.2, color='red', linestyle='--', label='Negative')
plt.xlabel('Negative                  Sentiment Polarity                  Positive')
plt.ylabel('Frequency')
plt.title('Distribution of Sentiment Polarity')
plt.legend()
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from ast import literal_eval
import pandas as pd
from itertools import chain

# %%
# Zip ratings and texts, filter out rows with a mismatch in counts, and explode the lists into separate rows
exploded_df = (
    df.apply(lambda row: list(zip(row['review_ratings'], row['review_texts'])) if pd.notna(row['review_ratings']).any() and pd.notna(row['review_texts']).any() else None, axis=1)
      .explode()
      .apply(pd.Series)
)

# Reset the index
exploded_df = exploded_df.reset_index(drop=True)

# Rename columns
exploded_df.columns = ['rating', 'text']

# Display the rearranged DataFrame
print(exploded_df)
# Separate reviews based on ratings
positive_reviews = ' '.join(exploded_df[exploded_df['rating'].isin([4, 5])]['text'])
negative_reviews = ' '.join(exploded_df[exploded_df['rating'].isin([1, 2])]['text'])
# Generate word clouds
positive_wordcloud = WordCloud(width=1200, height=800, background_color='white').generate(positive_reviews)
negative_wordcloud = WordCloud(width=1200, height=800, background_color='white').generate(negative_reviews)

# Plot the word clouds
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.imshow(positive_wordcloud, interpolation='bilinear')
plt.title('Positive Reviews Word Cloud')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(negative_wordcloud, interpolation='bilinear')
plt.title('Negative Reviews Word Cloud')
plt.axis('off')

plt.show()
# Out:
#        rating                                               text
# 0         5.0  Cash only for transactions under $5. \n\nAmazi...
# 1         3.0  Store is small with the front counter full of ...
# 2         4.0  I'm not a fan of tofu and neither is L so we d...
# 3         5.0  Love that this place kind of mimic the Asian n...
# 4         4.0  886 has been a great surprise. I was very skep...
# ...       ...                                                ...
# 42835     4.0  I came here for a family dinner - the decor of...
# 42836     1.0  AVOID ZYARA RESTAURANT. Shady and RUDE. Avoid,...
# 42837     3.0  Zyara, located on bustling Steinway Street, is...
# 42838     NaN                                                NaN
# 42839     NaN                                                NaN
#
# [42840 rows x 2 columns]

# %%
import nltk
nltk.download('punkt')
from nltk.corpus import stopwords
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Download the NLTK stop words
nltk.download('stopwords')

# Get the stop words
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\anuja\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\anuja\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Sample positive and negative reviews
positive_reviews = ' '.join(exploded_df[exploded_df['rating'].isin([4, 5])]['text'])
negative_reviews = ' '.join(exploded_df[exploded_df['rating'].isin([1, 2])]['text'])

# Tokenize the reviews
positive_tokens = nltk.word_tokenize(positive_reviews)
negative_tokens = nltk.word_tokenize(negative_reviews)

# Remove stop words
positive_tokens = [word for word in positive_tokens if word.lower() not in stop_words]
negative_tokens = [word for word in negative_tokens if word.lower() not in stop_words]

# Join the tokens back into strings
positive_reviews_no_stopwords = ' '.join(positive_tokens)
negative_reviews_no_stopwords = ' '.join(negative_tokens)

# WordCloud for positive reviews without stop words
wordcloud_positive = WordCloud(width=800, height=400, background_color='white').generate(positive_reviews_no_stopwords)
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud_positive, interpolation='bilinear')
plt.title('Positive Reviews Word Cloud (No Stop Words)')
plt.axis('off')
plt.show()

# WordCloud for negative reviews without stop words
wordcloud_negative = WordCloud(width=800, height=400, background_color='white').generate(negative_reviews_no_stopwords)
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud_negative, interpolation='bilinear')
plt.title('Negative Reviews Word Cloud (No Stop Words)')
plt.axis('off')
plt.show()
